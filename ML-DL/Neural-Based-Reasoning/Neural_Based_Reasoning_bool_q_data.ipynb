# %%
# !pip install tensorflow-datasets
# Out:
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.12/dist-packages (4.9.9)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (1.4.0)
# Requirement already satisfied: array_record>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (0.8.2)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (0.1.9)
# Requirement already satisfied: etils>=1.9.1 in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (1.13.0)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (4.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (2.0.2)
# Requirement already satisfied: promise in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (5.29.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (18.1.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (2.32.4)
# Requirement already satisfied: simple_parsing in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (0.1.7)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (1.17.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (3.2.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (0.10.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (4.67.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets) (2.0.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (0.8.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (2025.3.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (6.5.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (4.15.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->tensorflow-datasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->tensorflow-datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->tensorflow-datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->tensorflow-datasets) (2025.10.5)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.12/dist-packages (from dm-tree->tensorflow-datasets) (25.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from promise->tensorflow-datasets) (1.17.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.12/dist-packages (from simple_parsing->tensorflow-datasets) (0.17.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /usr/local/lib/python3.12/dist-packages (from tensorflow-metadata->tensorflow-datasets) (1.71.0)

# %%
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text as text
import tensorflow_datasets as tfds

# %%
def preprocess(example):
    question = example["question"]
    passage = example["passage"]
    label = tf.cast(example["answer"], tf.float32)
    return {"question": question, "passage": passage}, label

# %%
train_ds = tfds.load("bool_q", split="train").map(preprocess).batch(16).prefetch(tf.data.AUTOTUNE)
val_ds = tfds.load("bool_q", split="validation").map(preprocess).batch(16).prefetch(tf.data.AUTOTUNE)

# %%
class USELayer(tf.keras.layers.Layer):
    def __init__(self, model_url, **kwargs):
        super().__init__(**kwargs)
        self.use = hub.load(model_url)
    def call(self, inputs):
        embeddings = self.use(inputs)
        return tf.stop_gradient(embeddings)  # freeze weights

# ---- Define inputs ----
q_in = tf.keras.Input(shape=(), dtype=tf.string, name="question")
p_in = tf.keras.Input(shape=(), dtype=tf.string, name="passage")

# ---- Apply wrapped USE ----
use_layer = USELayer("https://tfhub.dev/google/universal-sentence-encoder/4")

# %%
q_embed = use_layer(q_in)
p_embed = use_layer(p_in)

# %%
combined = tf.keras.layers.Concatenate()([
    q_embed,
    p_embed,
    tf.keras.layers.Lambda(lambda x: tf.abs(x[0] - x[1]))([q_embed, p_embed])
])

# %%
x = tf.keras.layers.Dense(128, kernel_regularizer=tf.keras.regularizers.l2(1e-3))(combined)
x = tf.keras.layers.LeakyReLU(alpha=0.01)(x)
x = tf.keras.layers.Dropout(0.4)(x)

x = tf.keras.layers.Dense(64, kernel_regularizer=tf.keras.regularizers.l2(1e-3))(x)
x = tf.keras.layers.LeakyReLU(alpha=0.01)(x)
x = tf.keras.layers.Dropout(0.4)(x)

out = tf.keras.layers.Dense(1, activation="sigmoid")(x)


model = tf.keras.Model(inputs=[q_in, p_in], outputs=out)
model.compile(optimizer=tf.keras.optimizers.Adam(1e-4), loss="binary_crossentropy", metrics=["accuracy"])
model.summary()
# Out:
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ question            │ (None)            │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ passage             │ (None)            │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ use_layer_1         │ (None, 512)       │          0 │ question[0][0],   │
# │ (USELayer)          │                   │            │ passage[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 512)       │          0 │ use_layer_1[0][0… │
# │                     │                   │            │ use_layer_1[1][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 1536)      │          0 │ use_layer_1[0][0… │
# │ (Concatenate)       │                   │            │ use_layer_1[1][0… │
# │                     │                   │            │ lambda_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_26 (Dense)    │ (None, 128)       │    196,736 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_15      │ (None, 128)       │          0 │ dense_26[0][0]    │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 128)       │          0 │ leaky_re_lu_15[0… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_27 (Dense)    │ (None, 64)        │      8,256 │ dropout_18[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_16      │ (None, 64)        │          0 │ dense_27[0][0]    │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 64)        │          0 │ leaky_re_lu_16[0… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_28 (Dense)    │ (None, 1)         │         65 │ dropout_19[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 205,057 (801.00 KB)
#  Trainable params: 205,057 (801.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor='val_loss',   # metric to monitor
    patience=5,           # number of epochs with no improvement before stopping
    restore_best_weights=True,  # restore model weights from the epoch with best value of monitored metric
)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,            # large number; early stopping will stop earlier
    callbacks=[early_stop]
)
# Out:
# Epoch 1/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 18s 50ms/step - accuracy: 0.6175 - loss: 0.9692 - val_accuracy: 0.6217 - val_loss: 0.9033
# Epoch 2/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - accuracy: 0.6301 - loss: 0.8820 - val_accuracy: 0.6217 - val_loss: 0.8417
# Epoch 3/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 20s 47ms/step - accuracy: 0.6301 - loss: 0.8226 - val_accuracy: 0.6226 - val_loss: 0.7965
# Epoch 4/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 22s 51ms/step - accuracy: 0.6299 - loss: 0.7784 - val_accuracy: 0.6355 - val_loss: 0.7632
# Epoch 5/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 16s 54ms/step - accuracy: 0.6387 - loss: 0.7445 - val_accuracy: 0.6477 - val_loss: 0.7402
# Epoch 6/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 16s 54ms/step - accuracy: 0.6557 - loss: 0.7176 - val_accuracy: 0.6401 - val_loss: 0.7245
# Epoch 7/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 16s 54ms/step - accuracy: 0.6658 - loss: 0.6986 - val_accuracy: 0.6462 - val_loss: 0.7112
# Epoch 8/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - accuracy: 0.6680 - loss: 0.6877 - val_accuracy: 0.6443 - val_loss: 0.7022
# Epoch 9/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 21s 47ms/step - accuracy: 0.6755 - loss: 0.6739 - val_accuracy: 0.6404 - val_loss: 0.6966
# Epoch 10/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - accuracy: 0.6797 - loss: 0.6636 - val_accuracy: 0.6401 - val_loss: 0.6918
# Epoch 11/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 20s 47ms/step - accuracy: 0.6874 - loss: 0.6549 - val_accuracy: 0.6367 - val_loss: 0.6876
# Epoch 12/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - accuracy: 0.6916 - loss: 0.6457 - val_accuracy: 0.6379 - val_loss: 0.6847
# Epoch 13/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - accuracy: 0.6909 - loss: 0.6416 - val_accuracy: 0.6376 - val_loss: 0.6838
# Epoch 14/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 20s 47ms/step - accuracy: 0.6969 - loss: 0.6346 - val_accuracy: 0.6407 - val_loss: 0.6798
# Epoch 15/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - accuracy: 0.7042 - loss: 0.6266 - val_accuracy: 0.6352 - val_loss: 0.6812
# Epoch 16/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - accuracy: 0.7114 - loss: 0.6204 - val_accuracy: 0.6443 - val_loss: 0.6764
# Epoch 17/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 21s 47ms/step - accuracy: 0.7141 - loss: 0.6174 - val_accuracy: 0.6355 - val_loss: 0.6777
# Epoch 18/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 21s 48ms/step - accuracy: 0.7207 - loss: 0.6104 - val_accuracy: 0.6385 - val_loss: 0.6762
# Epoch 19/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 15s 50ms/step - accuracy: 0.7196 - loss: 0.6070 - val_accuracy: 0.6407 - val_loss: 0.6760
# Epoch 20/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - accuracy: 0.7281 - loss: 0.6004 - val_accuracy: 0.6425 - val_loss: 0.6742
# Epoch 21/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 16s 53ms/step - accuracy: 0.7340 - loss: 0.5953 - val_accuracy: 0.6425 - val_loss: 0.6778
# Epoch 22/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - accuracy: 0.7340 - loss: 0.5902 - val_accuracy: 0.6434 - val_loss: 0.6772
# Epoch 23/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - accuracy: 0.7365 - loss: 0.5863 - val_accuracy: 0.6483 - val_loss: 0.6762
# Epoch 24/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - accuracy: 0.7472 - loss: 0.5789 - val_accuracy: 0.6502 - val_loss: 0.6756
# Epoch 25/50
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step - accuracy: 0.7557 - loss: 0.5746 - val_accuracy: 0.6480 - val_loss: 0.6781

# %%
sample = {
    "question": tf.constant(["How are you??"]),
    "passage": tf.constant(["I am good"])
}

pred = model.predict(sample)
score = float(pred[0][0])  # explicitly extract scalar
print("Prediction:", score)
print("Answer:", "True" if score > 0.5 else "False")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Prediction: 0.5580454468727112
# Answer: True
